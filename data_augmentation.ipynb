# %% [markdown]
# <a href="https://colab.research.google.com/github/adithya-prabhu-22/deep_learning_algos/blob/main/data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img= image.load_img("/content/37.jpg")

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
datagenerator=ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2
)

# %%
import numpy as np
img=np.array(img)

# %%
type(image)
# Out:
# module

# %%
img.shape
# Out:
# (337, 500, 3)

# %%
input_batch=img.reshape(1,337,500,3)

# %%
import os


if not os.path.exists('augmented'):
    os.makedirs('augmented')

i=0
for batch in datagenerator.flow(input_batch,batch_size=1,save_to_dir='augmented'):
  i=i+1
  if i==10:
    break

# %%
input_batch.shape
# Out:
# (1, 337, 500, 3)
